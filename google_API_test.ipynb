# %%
import pandas as pd
import googlemaps
import requests
import time
import json

# %%
gmaps = googlemaps.Client(key='AIzaSyCFE5vqPizwOgd_vvDWWipZnRm2bNlHdAo')

# %%
#not needed i guess

#url = "https://maps.googleapis.com/maps/api/place/textsearch/json?query=grocery%20stores%20in%20Nashville%20Tennessee&key=AIzaSyCFE5vqPizwOgd_vvDWWipZnRm2bNlHdAo"

#payload={}
#headers = {}

#response = requests.request('GET', url, headers=headers, data=payload)

# %%
grocery_stores = []
params1 = {}

endpoint_url1 = "https://maps.googleapis.com/maps/api/place/textsearch/json?query=grocery%20stores%20in%20Nashville%20Tennessee&key=AIzaSyCFE5vqPizwOgd_vvDWWipZnRm2bNlHdAo"
         
res1 = requests.get(endpoint_url1, params = params1)
results1 =  json.loads(res1.content)
grocery_stores.extend(results1['results'])
time.sleep(2)
while "next_page_token" in results1:
     params1['pagetoken'] = results1['next_page_token'],
     res1 = requests.get(endpoint_url1, params = params1)
     results1 = json.loads(res1.content)
     grocery_stores.extend(results1['results'])
     time.sleep(2)

# %%
print(results1)
# Out:
# {'html_attributions': [], 'results': [{'business_status': 'OPERATIONAL', 'formatted_address': '3636 Bell Rd, Nashville, TN 37214, United States', 'geometry': {'location': {'lat': 36.1504959, 'lng': -86.6272429}, 'viewport': {'northeast': {'lat': 36.15195372989272, 'lng': -86.62572617010727}, 'southwest': {'lat': 36.14925407010728, 'lng': -86.62842582989272}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png', 'icon_background_color': '#4B96F3', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet', 'name': 'Food Lion', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108438863711529282914">James Lozano</a>'], 'photo_reference': 'Aap_uEBLfcnnbySoB4ASF8QqUIVHLY9RkzNMCyr89NTseA3RDrzgsvgUBWfg6kVam2R3ZTcGWV2BlrkpQoP2Ol02xhgXPrseWVxI-WL89hN0uJTR5w_sOlBxYKBUHUehAiIZfh7U3HmeDXBLATH7SHObOTeP5L3TZVzy5JC9WYjBov-n4mkK', 'width': 4032}], 'place_id': 'ChIJE3dWdaJrZIgRW4OfgwEsj8I', 'plus_code': {'compound_code': '592F+54 Nashville, Tennessee', 'global_code': '868M592F+54'}, 'price_level': 2, 'rating': 4.2, 'reference': 'ChIJE3dWdaJrZIgRW4OfgwEsj8I', 'types': ['grocery_or_supermarket', 'food', 'point_of_interest', 'store', 'establishment'], 'user_ratings_total': 1122}, {'business_status': 'OPERATIONAL', 'formatted_address': '391 Elysian Fields Ct, Nashville, TN 37211, United States', 'geometry': {'location': {'lat': 36.0874399, 'lng': -86.7290707}, 'viewport': {'northeast': {'lat': 36.08870397989272, 'lng': -86.72780657010728}, 'southwest': {'lat': 36.08600432010728, 'lng': -86.73050622989273}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png', 'icon_background_color': '#4B96F3', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet', 'name': 'Azadi International Food Market & Bakery', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3348, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113026534009199891672">Uzzal Hasan</a>'], 'photo_reference': 'Aap_uEA68VuxGs_wG7skNQztyb83TYwXXXXymenTyVHrCc7PQVgOXDI04oH0UJRyEjbKp0jGdo-LcMkYoabHrHlfSgQd5ICBVFO1kMd9vllu7dKzyDvsdA6eNsWLpnpCv_psWdjaZxb6VziEGSIjFEBbYT3K1jNwzgLKMjliI5_8ut6iya5a', 'width': 5952}], 'place_id': 'ChIJOfeOnZ1vZIgRxqpA36CAo4k', 'plus_code': {'compound_code': '37PC+X9 Nashville, Tennessee', 'global_code': '868M37PC+X9'}, 'rating': 4.4, 'reference': 'ChIJOfeOnZ1vZIgRxqpA36CAo4k', 'types': ['grocery_or_supermarket', 'food', 'point_of_interest', 'store', 'establishment'], 'user_ratings_total': 324}, {'business_status': 'OPERATIONAL', 'formatted_address': '143 McGavock Pk, Nashville, TN 37214, United States', 'geometry': {'location': {'lat': 36.1708586, 'lng': -86.6787306}, 'viewport': {'northeast': {'lat': 36.17232252989272, 'lng': -86.67757242010727}, 'southwest': {'lat': 36.16962287010728, 'lng': -86.68027207989272}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png', 'icon_background_color': '#4B96F3', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet', 'name': 'Kroger', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113890435250045612467">sweetsunnydaygirl</a>'], 'photo_reference': 'Aap_uEDU067WDgViYnql9DMJH031UInW9IWuMU3iUjHsD8y7KE61MupGWdvBkPx52EUOWnx-82UFpfeQHGuNpB9zbg-K7mP7ucmrlUooveVwfDpn2l3L4xzBI_V35jUq0Y8o0RUoAzMnjNgHO2c8OYdm4I0bgWNtspog23Ijhja37aOkJkNu', 'width': 4032}], 'place_id': 'ChIJ01nR5XRpZIgR9acvgLYOuAA', 'plus_code': {'compound_code': '58CC+8G Nashville, Tennessee', 'global_code': '868M58CC+8G'}, 'price_level': 2, 'rating': 4, 'reference': 'ChIJ01nR5XRpZIgR9acvgLYOuAA', 'types': ['grocery_or_supermarket', 'food', 'point_of_interest', 'store', 'establishment'], 'user_ratings_total': 887}, {'business_status': 'OPERATIONAL', 'formatt ...

# %%
shop_name1 = []
formatted_address1 = []
shop_lat1 = []
shop_lng1 = []

for i in range(len(grocery_stores)):
    shop = grocery_stores[i]

    try:
        shop_name1.append(shop['name'])
    except:
        shop_name1.append('none')

    try:
        formatted_address1.append(shop['formatted_address'])
    except:
        formatted_address1.append('none')

    try:
        shop_lat1.append(shop['geometry']['location']['lat'])
    except:
        shop_lat1.append('none')

    try:
        shop_lng1.append(shop['geometry']['location']['lng'])
    except:
        shop_lng1.append('none')

# %%
df_dict1 = {'shop_name':shop_name1, 'shop_address':formatted_address1, 'shop_lat':shop_lat1, 'shop_lng':shop_lng1}

grocery_stores_df = pd.DataFrame(df_dict1)
#grocery_stores_df['data_zipcode'] = data_zipcode
grocery_stores_df['duplicator'] = grocery_stores_df['shop_name'] + grocery_stores_df['shop_address']

grocery_stores_df.drop_duplicates(['duplicator'], inplace=True)

#all_grocery_stores = all_grocery_stores.append(grocery_stores_df)

# %%
grocery_stores_df.shape
# Out:
# (60, 5)

# %%
grocery_stores_df
# Out:
#                                             shop_name  \
# 0                                       Piggly Wiggly
# 1                                  Whole Foods Market
# 2                 Publix Super Market at Capitol View
# 3                                              Kroger
# 4                                  Whole Foods Market
# 5                            The Turnip Truck - Gulch
# 6                                        Trader Joe's
# 7                                   Savi Urban Market
# 8                              Resha's Bi-Rite Market
# 9                                      Swett's Market
# 10                                             Kroger
# 11                  The Turnip Truck - East Nashville
# 12                                  Osborne's Bi-Rite
# 13                                             Kroger
# 14                                     Rosie's Market
# 15                                   K&S World Market
# 16                                       Trader Joe's
# 17  Publix Super Market at Hill Center at Nashvill...
# 18                                             Kroger
# 19  Publix Super Market at Hill Center at Belle Meade
# 20                                   Aleksey's Market
# 21                                         Save A Lot
# 22                             Sprouts Farmers Market
# 23                                      Piggly Wiggly
# 24                 Fresh & Fresh International Market
# 25                                             Kroger
# 26                                             Kroger
# 27               Publix Super Market at The Crossings
# 28                     Publix Super Market at Melrose
# 29                               H G Hill Food Stores
# 30                                             Kroger
# 31                                  The Produce Place
# 32                                             Kroger
# 33                                A AND M Marketplace
# 34                                Uptown Fruit Market
# 35                                               ALDI
# 36                           InterAsian Market & Deli
IzaSyCFE5vqPizwOgd_vvDWWipZnRm2bNlHdAo"
         
#res2 = requests.get(endpoint_url2, params = params2)
#results2 =  json.loads(res2.content)
#restaurants.extend(results2['results'])
#time.sleep(2)
#while "next_page_token" in results2:
     #params2['pagetoken'] = results2['next_page_token'],
     #res2 = requests.get(endpoint_url2, params = params2)
     #results2 = json.loads(res2.content)
     #restaurants.extend(results2['results'])
     #time.sleep(2)

# %%
restaurants = []
params2 = {}

endpoint_url2 = 'https://maps.googleapis.com/maps/api/place/textsearch/json?query=nashville+tn&type=restaurant&key=AIzaSyCFE5vqPizwOgd_vvDWWipZnRm2bNlHdAo'
         
res2 = requests.get(endpoint_url2, params = params2)
results2 =  json.loads(res2.content)
restaurants.extend(results2['results'])
time.sleep(2)
while "next_page_token" in results2:
     params2['pagetoken'] = results2['next_page_token'],
     res2 = requests.get(endpoint_url2, params = params2)
     results2 = json.loads(res2.content)
     restaurants.extend(results2['results'])
     time.sleep(2)

# %%
results2
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': '2100 West End Ave, Nashville, TN 37203, United States',
#    'geometry': {'location': {'lat': 36.15064, 'lng': -86.8020943},
#     'viewport': {'northeast': {'lat': 36.15185907989272,
#       'lng': -86.80088852010728},
#      'southwest': {'lat': 36.14915942010727, 'lng': -86.80358817989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': "Mason's Nashville",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2120,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115154328634129165379">JeAnne Swinley</a>'],
#      'photo_reference': 'Aap_uEAN58S_bnWvXK10PQjrr8o3Di3n31IgMDJkS1MZ3N2KQNPoDbXZkQjfKOBWg_dwBdm0IjYWyBX9TV-vnH1l8Sm2rBF3pV6cSlcVEJi4UZ6bWUIPRnFD17uxMIwQpye777_Ag98AApw1RseoUXUXFQ6CMeMrcO_tWQftCWrGcnKF6Xj8',
#      'width': 3771}],
#    'place_id': 'ChIJSf7y-pVmZIgR1ld68nKuAfY',
#    'plus_code': {'compound_code': '552X+75 Nashville, Tennessee',
#     'global_code': '868M552X+75'},
#    'price_level': 2,
#    'rating': 4.2,
#    'reference': 'ChIJSf7y-pVmZIgR1ld68nKuAfY',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 34},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '144 Rep. John Lewis Way S, Nashville, TN 37203, United States',
#    'geometry': {'location': {'lat': 36.1597811, 'lng': -86.7778481},
#     'viewport': {'northeast': {'lat': 36.16109457989272,
#       'lng': -86.77653657010728},
#      'southwest': {'lat': 36.15839492010728, 'lng': -86.77923622989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Trattoria Il Mulino',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 5304,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113858294643673817224">Rajiv Vyas</a>'],
#      'photo_reference': 'Aap_uEBFahlXcSNtvYcFqdPwPv-ZRhjlA0glmS57Nt5kECxFDT-lC3aPpV61uHPySU7XO5vGLIeypFmaqAag2S1ACURrSWbkd0h6gfMIP6JUcwJ8MS0BxongdWv-WT-XesNu0guQ4hX6IgNk5SKysUX8eXkQwc_ODgWWcncaR6DQacD9J4Ez',
#      'width': 7952}],
#    'place_id': 'ChIJXWRKrF5mZIgRqFZFC1wslCw',
#    'plus_code': {'compound_code': '565C+WV Nashville, Tennessee',
#     'global_code': '868M565C+WV'},
#    'price_level': 2,
#    'rating': 4.4,
#    'reference': 'ChIJXWRKrF5mZIgRqFZFC1wslCw',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 794},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '901 Gleaves St, Nashville, TN 37203, United States',
#    'geometry': {'location': {'lat': 36.1517753, 'lng': -86.7808761},
#     'viewport': {'northeast': {'lat': 36.15322312989272,
#       'lng': -86.77954282010728},
#      'southwest': {'lat': 36.15052347010727, 'lng': -86.78224247989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Stock & Barrel',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101131456856956824820">Matthew Tyndall</a>'],
#      'photo_reference': 'Aap_uECGo_KT78QOrZ90mfATsVo9vrtmELu8lthlj-UDp9eMhdGMUh-89Uh8sRhm2EfOR2pj79FgwhQL4N0lXp18MD0hJJWiAjqxpsdfa1NnujQCHlGlqqe0m7QTKb0Sh3WJzuw-4FteV71tOYQxLe6xfcyVNQPQvw8OZjn5NkksnIQm-kff',
#      'width': 4032}],
#    'place_id': 'ChIJlxNSs5pnZIgRGzVlhk2V3sc',
#    'plus_code': {'compound_code': '5629+PJ Nashville, Tennessee',
#     'global_code': '868M5629+PJ'},
#    'price_level': 2,
#    'rating': 4.6,
#    'reference': 'ChIJlxNSs5pnZIgRGzVlhk2V3sc',
#    'types': ['restaurant',
#     'bar',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 504},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '210 4th Ave N, Nashville, TN 37219, United States',
#    'geometry': {'location': {'lat': 36.1642022, 'lng': -86.7789669},
#     'viewport': {'northeast': {'lat': 36.16549052989272,
#       'lng': -86.77772792010728},
#      'southwest': {'lat': 36.16279087010727, 'lng': -86.78042757989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Stateside Kitchen',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110323847257548426689">Simon Katan</a>'],
#      'photo_reference': 'Aap_uEBHB44cgAPFVuyDiLJEW9vZ5kc0rq3nGeIr0_UXewz8A8EIpCHrUk9CWOfq5KoIcYllM6OkkB4D6yPIWYOf5OH681idb6Qim7GykDi4h87Pqk8w6svPbIcrHTTeMu5xn-ZdLw54BbsMW-0vI_9G4N8h1rJkaSBUy01tlu2QwP7I9cDw',
#      'width': 4032}],
#    'place_id': 'ChIJQ_U-ZadnZIgR8GCAIIRVKa8',
#    'plus_code': {'compound_code': '567C+MC Nashville, Tennessee',
#     'global_code': '868M567C+MC'},
#    'rating': 4.2,
#    'reference': 'ChIJQ_U-ZadnZIgR8GCAIIRVKa8',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 273},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '150 3rd Ave S #110, Nashville, TN 37201, United States',
#    'geometry': {'location': {'lat': 36.1602036, 'lng': -86.77464429999999},
#     'viewport': {'northeast': {'lat': 36.16140962989272,
#       'lng': -86.77327642010728},
#      'southwest': {'lat': 36.15870997010728, 'lng': -86.77597607989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'The Southern Steak & Oyster',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2268,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107939186360300971384">Doug Plagemann</a>'],
#      'photo_reference': 'Aap_uEBx2-ekizZ2rq0ovfO4ySVi9uqUIET_AXUbkhUuELENAuhJuTsOuB8hc9CCe_PA24VueuBvNy-918sQC6E2-W2n0XjMVnul7z7mpScyHW_1Xhz6AYU1UJjS_gROZ5ls3mLhmK8afTZoF2obKMQD4gQRdSdyOyDfm0fXJELMg7wGTVy_',
#      'width': 4032}],
#    'place_id': 'ChIJsYdleVxmZIgRHQQR1E-Fn38',
#    'plus_code': {'compound_code': '566G+34 Nashville, Tennessee',
#     'global_code': '868M566G+34'},
#    'price_level': 3,
#    'rating': 4.5,
#    'reference': 'ChIJsYdleVxmZIgRHQQR1E-Fn38',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2772},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '719 8th Ave S, Nashville, TN 37203, United States',
#    'geometry': {'location': {'lat': 36.1499434, 'lng': -86.7794783},
#     'viewport': {'northeast': {'lat': 36.15117037989272,
#       'lng': -86.77797892010729},
#      'southwest': {'lat': 36.14847072010728, 'lng': -86.78067857989274}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Party Fowl',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108845655573861017615">Joshua Stock</a>'],
#      'photo_reference': 'Aap_uEBgNYhYpv1cNhW3DbfxjbZeSyN09aMeKsPtv6H7QrvsK_BA4OH3uYe6od6hPsEgusfPt1x1oHtvdaWFgp23w1VYtbEniJeajG9t1IzdoXHjMwOIydSCHkVvdcLcziCHfStEzB3XhiEWocL0N9JhgWk-2DcUKJ4d22oYs-4tWH5_9oXX',
#      'width': 4032}],
#    'place_id': 'ChIJY5yLgmFmZIgR5amgjKlwhVo',
#    'plus_code': {'compound_code': '46XC+X6 Nashville, Tennessee',
#     'global_code': '868M46XC+X6'},
#    'price_level': 2,
#    'rating': 4.3,
#    'reference': 'ChIJY5yLgmFmZIgR5amgjKlwhVo',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2501},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '902 Main St, Nashville, TN 37206, United States',
#    'geometry': {'location': {'lat': 36.1758957, 'lng': -86.7568201},
#     'viewport': {'northeast': {'lat': 36.17733097989272,
#       'lng': -86.75553487010728},
#      'southwest': {'lat': 36.17463132010728, 'lng': -86.75823452989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Butcher & Bee',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3840,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103373804951490048854">Derek Lee</a>'],
#      'photo_reference': 'Aap_uEDh4FYLQsrpYsYV42k4QZUBJ1ZSlieVcgOQfQQYBKm5x0qka5UEfZeziJDZncD2Z8sCqqZqA0hmbmERHlV0enJ_RZfTPgs7CgA2_8ZB4HkMgf1N5fv8yb1i6O2dzksv763u23pw2vUSPt82qtwn4iomly6F5S2gHHQJScr0DDb7NcNq',
#      'width': 5760}],
#    'place_id': 'ChIJl4d3qsxnZIgRNDFlj8W0hvw',
#    'plus_code': {'compound_code': '56GV+97 Nashville, Tennessee',
#     'global_code': '868M56GV+97'},
#    'price_level': 2,
#    'rating': 4.5,
#    'reference': 'ChIJl4d3qsxnZIgRNDFlj8W0hvw',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1672},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'formatted_address': '166 2nd Ave N Ste A, Nashville, TN 37201, United States',
#    'geometry': {'location': {'lat': 36.1639844, 'lng': -86.7762151},
#     'viewport': {'northeast': {'lat': 36.16524582989272,
#       'lng': -86.77496242010727},
#      'southwest': {'lat': 36.16254617010727, 'lng': -86.77766207989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'The Melting Pot',
#    'permanently_closed': True,
#    'photos': [{'height': 2946,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117855250670249598614">The Melting Pot</a>'],
#      'photo_reference': 'Aap_uEAaVy6zl8aUCYfl7wh4d-ouCMiS81QZCj8oHIeL6vyH5Q8FHOpfqB6aXYZ361p5DuG--AC3LmuizvCtpyuscM51Ez5TodNe2cqwck8QYFqNtASvr7z6lckj1X6LGdywMjMmMaXpUsSs-sarh3R_P7XBzlvK6IaC7durFNjz_zweBOXN',
#      'width': 4420}],
#    'place_id': 'ChIJrZtXPFpmZIgRVuCamO3fcVE',
#    'plus_code': {'compound_code': '567F+HG Nashville, Tennessee',
#     'global_code': '868M567F+HG'},
#    'price_level': 3,
#    'rating': 4.6,
#    'reference': 'ChIJrZtXPFpmZIgRVuCamO3fcVE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 894},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '3001 West End Ave, Nashville, TN 37203, United States',
#    'geometry': {'location': {'lat': 36.14364, 'lng': -86.81345999999999},
#     'viewport': {'northeast': {'lat': 36.14515087989272,
#       'lng': -86.81224997010727},
#      'southwest': {'lat': 36.14245122010728, 'lng': -86.81494962989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': "Taziki's Mediterranean Cafe - West End",
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2560,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107840762646903366592">Vincent Vizza</a>'],
#      'photo_reference': 'Aap_uEBbUpHNURg4OIgLpw_3HTfI3US8XI7EobiqJNrR3b6W_d6LSbukLsgm5GnUinoEscIbujaY6QfIeFUudHqLvGlu8dtn_lcxjCOQIIzTAeeCj7ni6FUIiwtFsWLAnuJUWN5ICMLe5riiNjHPodLDB4ZNtd6X75Nu_y_wsQSlwxVo4MhX',
#      'width': 1920}],
#    'place_id': 'ChIJ19HDwK9mZIgR3bv6HoBC2lY',
#    'plus_code': {'compound_code': '45VP+FJ Nashville, Tennessee',
#     'global_code': '868M45VP+FJ'},
#    'price_level': 2,
#    'rating': 4.4,
#    'reference': 'ChIJ

#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2268,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101188230284217457252">Steven Flores</a>'],
#      'photo_reference': 'Aap_uEBnly4YkENdEhEywTS3Y70F0WFRSzFtikjyTGaLjZV-ySVyfAciQvGwrSX54QnYY2C9q16S4YoQIh5Pv3p5Ft2aRJiWgyRNED4gnz4kOnJ8zRgxJX5VTmkFscHonAgWjhJE2cE2LnJefIkDllJ8kfES7gEE2D4lG9eputoPlXcVBBYP',
#      'width': 4032}],
#    'place_id': 'ChIJO4vswZZmZIgRjGwiMJIaBMU',
#    'plus_code': {'compound_code': '46X2+8M Nashville, Tennessee',
#     'global_code': '868M46X2+8M'},
#    'price_level': 3,
#    'rating': 4.4,
#    'reference': 'ChIJO4vswZZmZIgRjGwiMJIaBMU',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 312},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '2506 12th Ave S, Nashville, TN 37204, United States',
#    'geometry': {'location': {'lat': 36.124974, 'lng': -86.789155},
#     'viewport': {'northeast': {'lat': 36.12642882989272,
#       'lng': -86.78797552010728},
#      'southwest': {'lat': 36.12372917010728, 'lng': -86.79067517989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Urban Grub',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1536,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107222926279340248734">Valerie Paxton</a>'],
#      'photo_reference': 'Aap_uEC7y6Tj06lsphGtETZgOM82Jylm8MwmBRdRbLDa_36g53Qmwx9vQhfW1ac60Ogfwq15EO3TVxTjCFS3lR2ohOfIuRBbpM1w6C01Rs6v4b4EGTQ6mlUKr0ExQs-jQZhrH42AeVbeU6wWvMEPS7tsBpSUCJs8J4Hx7JnWMrna2hQ8nOxn',
#      'width': 2048}],
#    'place_id': 'ChIJI8ZqVC5kZIgRTUtWeHRCw8s',
#    'plus_code': {'compound_code': '46F6+X8 Nashville, Tennessee',
#     'global_code': '868M46F6+X8'},
#    'price_level': 3,
#    'rating': 4.5,
#    'reference': 'ChIJI8ZqVC5kZIgRTUtWeHRCw8s',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 2000},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '210 Almond St, Nashville, TN 37201, United States',
#    'geometry': {'location': {'lat': 36.1589012, 'lng': -86.7749226},
#     'viewport': {'northeast': {'lat': 36.16024057989272,
#       'lng': -86.77361177010728},
#      'southwest': {'lat': 36.15754092010727, 'lng': -86.77631142989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'The Farm House',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3264,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111634393695283057241">Robert Ropars</a>'],
#      'photo_reference': 'Aap_uEAunSIBjSS6Z6E5s4nUS_76vXUTP77vQn0-Q-_FpmhXuBVlK89ac7VlUW0HsREq5AZmXwosNsG7dyNempFv_09hpkoaCeQPEc9ivfpJ55UzMB4-ZFan9tKjp0TpnKOlo7nWnn6wVcoiReSdDRNaH1x6EJ_57Q4RcISrpfZCFiMnXUxr',
#      'width': 2448}],
#    'place_id': 'ChIJy6WmblxmZIgRASzakrChToc',
#    'plus_code': {'compound_code': '565G+H2 Nashville, Tennessee',
#     'global_code': '868M565G+H2'},
#    'price_level': 2,
#    'rating': 4.3,
#    'reference': 'ChIJy6WmblxmZIgRASzakrChToc',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 673},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'formatted_address': '209 10th Ave S #223, Nashville, TN 37203, United States',
#    'geometry': {'location': {'lat': 36.155439, 'lng': -86.7825833},
#     'viewport': {'northeast': {'lat': 36.15675402989272,
#       'lng': -86.78111382010727},
#      'southwest': {'lat': 36.15405437010727, 'lng': -86.78381347989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'M',
#    'permanently_closed': True,
#    'photos': [{'height': 854,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103860836980792951078">A Google User</a>'],
#      'photo_reference': 'Aap_uEBibn5ZysF7IbtVPj-R3vYKV31wezG6SM9QHb_wnLsDtObYZs0yG2v61GxFzTS6CtWWmi_oFRJckEdHAVo64jUfPxaBwy4edcSfd7ja_IWgf-7TlbNH67O6La2zF9qfiakgBbydHCEjs9-TejCBMYhrtyB9oeL-IvawlFOnNasz0l3x',
#      'width': 1280}],
#    'place_id': 'ChIJVxKDsopmZIgRMPCOiLw01Hk',
#    'plus_code': {'compound_code': '5648+5X Nashville, Tennessee',
#     'global_code': '868M5648+5X'},
#    'price_level': 3,
#    'rating': 4.5,
#    'reference': 'ChIJVxKDsopmZIgRMPCOiLw01Hk',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 245},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'formatted_address': '620 Taylor St, Nashville, TN 37208, United States',
#    'geometry': {'location': {'lat': 36.17751459999999,
#      'lng': -86.79226580000001},
#     'viewport': {'northeast': {'lat': 36.17888187989272,
#       'lng': -86.79092787010728},
#      'southwest': {'lat': 36.17618222010728, 'lng': -86.79362752989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Tailor Nashville',
#    'permanently_closed': True,
#    'photos': [{'height': 2183,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108150974919215622605">Matt Taylor</a>'],
#      'photo_reference': 'Aap_uECo48Nq9TGhqBmw8z473-1es27_VVO5HN0kIuylorqlM_aGOpch-6WI2EJSMIKkgv3pAf_xlWNufB5IBy4JyYostj__XbpO_ERUwjR6YMzlXwQyLnlVRsUv9SUaht6-bKjf4MR1YM0pa-Svwg68GBQIahFir67CFdjjm81YVuWWmRta',
#      'width': 3882}],
#    'place_id': 'ChIJpRw3GcNnZIgRzEvUjPtmjfA',
#    'plus_code': {'compound_code': '56H5+23 Nashville, Tennessee',
#     'global_code': '868M56H5+23'},
#    'rating': 4.8,
#    'reference': 'ChIJpRw3GcNnZIgRzEvUjPtmjfA',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 109},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '1222 4th Ave N, Nashville, TN 37208, United States',
#    'geometry': {'location': {'lat': 36.176923, 'lng': -86.787262},
#     'viewport': {'northeast': {'lat': 36.17824877989272,
#       'lng': -86.78602702010727},
#      'southwest': {'lat': 36.17554912010728, 'lng': -86.78872667989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'City House',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100828929377552447807">Nico Lee</a>'],
#      'photo_reference': 'Aap_uEAgNNswx3-XBhdg1mXHmBJ_8c3IuHHcwgJNSPy5AVWltBBSbdzfzaZ6xY7OySD_MdXPZy5xSGAafGymILJbSLFEKikaG0YCsLCNbu76jfukd1lIZGZfgIHWnZsj39HlH3GVS7qXt4h6GU2w5r8-ixqRuenZ5UzyOjYtyKAPCbIXOk2b',
#      'width': 3840}],
#    'place_id': 'ChIJizjhXHJmZIgRFuDelhALHY8',
#    'plus_code': {'compound_code': '56G7+Q3 Nashville, Tennessee',
#     'global_code': '868M56G7+Q3'},
#    'price_level': 2,
#    'rating': 4.5,
#    'reference': 'ChIJizjhXHJmZIgRFuDelhALHY8',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 733},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '401 11th Ave S, Nashville, TN 37203, United States',
#    'geometry': {'location': {'lat': 36.1525355, 'lng': -86.7840899},
#     'viewport': {'northeast': {'lat': 36.15375687989272,
#       'lng': -86.78263792010728},
#      'southwest': {'lat': 36.15105722010728, 'lng': -86.78533757989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Marsh House',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118291960673837671524">Luke Beard</a>'],
#      'photo_reference': 'Aap_uEAMuhyLgjboIGbJ7dyVnmXXQa73gghwIt8N7KL6FHd-km0xq6rnC9UBdl_5IACMXF3UPyCU-XhywI_DjrQoIaOUvXSiC3IXTffU3ZSmdpWIuu-eZuzUyNjG8D64f7qezscmCCYxPnTqDtKHUMN7MJ31TBxQMYaVtxtmcZv3dJTnHXyL',
#      'width': 2000}],
#    'place_id': 'ChIJj_hz54pmZIgRgCWp8HofZOw',
#    'plus_code': {'compound_code': '5638+29 Nashville, Tennessee',
#     'global_code': '868M5638+29'},
#    'price_level': 3,
#    'rating': 4.5,
#    'reference': 'ChIJj_hz54pmZIgRgCWp8HofZOw',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 555},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '700 Taylor St, Nashville, TN 37208, United States',
#    'geometry': {'location': {'lat': 36.1775389, 'lng': -86.7928833},
#     'viewport': {'northeast': {'lat': 36.17879087989272,
#       'lng': -86.79148122010729},
#      'southwest': {'lat': 36.17609122010728, 'lng': -86.79418087989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Rolf and Daughters',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3036,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107188771173434936250">Thomas Appleton</a>'],
#      'photo_reference': 'Aap_uEAlKHmamrCya8udTS-EcdzlOIx0el1lcOvDKKSLtE3_2nqOp1AvIuGXetDQguS_231CJYYj8PasDoK4E8tKwnXqnvSuG-bBjgukw0YXAUshwTqfhgK5tFCTEohLlkYm6O_-Nr135-H_mf7ZVePLzyAZ1ydKhil1tYbFBYelOFjdkwqa',
#      'width': 4048}],
#    'place_id': 'ChIJSy7tWh1nZIgR7o6crVziEqY',
#    'plus_code': {'compound_code': '56H4+2R Nashville, Tennessee',
#     'global_code': '868M56H4+2R'},
#    'price_level': 3,
#    'rating': 4.6,
#    'reference': 'ChIJSy7tWh1nZIgR7o6crVziEqY',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 835}],
#  'status': 'OK'}

# %%
shop_name2 = []
formatted_address2 = []
shop_lat2 = []
shop_lng2 = []

for i in range(len(restaurants)):
    shop2 = restaurants[i]

    try:
        shop_name2.append(shop2['name'])
    except:
        shop_name2.append('none')

    try:
        formatted_address2.append(shop2['formatted_address'])
    except:
        formatted_address2.append('none')

    try:
        shop_lat2.append(shop2['geometry']['location']['lat'])
    except:
        shop_lat2.append('none')

    try:
        shop_lng2.append(shop2['geometry']['location']['lng'])
    except:
        shop_lng2.append('none')

# %%
df_dict2 = {'shop_name':shop_name2, 'shop_address':formatted_address2, 'shop_lat':shop_lat2, 'shop_lng':shop_lng2}

restaurants_df = pd.DataFrame(df_dict2)
#grocery_stores_df['data_zipcode'] = data_zipcode
restaurants_df['duplicator'] = restaurants_df['shop_name'] + restaurants_df['shop_address']

restaurants_df.drop_duplicates(['duplicator'], inplace=True)

#all_grocery_stores = all_grocery_stores.append(grocery_stores_df)

# %%
restaurants_df.shape
# Out:
# (60, 5)

# %%
restaurants_df
# Out:
#                                             shop_name  \
# 0               Fleming’s Prime Steakhouse & Wine Bar
# 1                               Moe's Southwest Grill
# 2                       J. Alexander's Redlands Grill
# 3                                          BrickTop's
# 4                               Central Bar + Kitchen
# 5                                        P.F. Chang's
# 6                          Amerigo Italian Restaurant
# 7                              Hattie B's Hot Chicken
# 8                                    The Catbird Seat
# 9                                                Nada
# 10                                       Midtown Cafe
# 11                                             Henley
# 12                                    The 404 Kitchen
# 13                                  Adele's Nashville
# 14                            Maggiano's Little Italy
# 15                                    The Mockingbird
# 16                                         Poke Bros.
# 17                                        Cabana Taps
# 18                             Kayne Prime Steakhouse
# 19                                Rotier's Restaurant
# 20                              The Row Kitchen & Pub
# 21                                               Etch
# 22                                  Red's 615 Kitchen
# 23                           Arnold's Country Kitchen
# 24                                           Flatiron
# 25                            The Chef and I on Ninth
# 26                           Jimmy Kelly’s Steakhouse
# 27                                           Pastaria
# 28                                           Hathorne
# 29  Puckett's Grocery & Restaurant - Downtown Nash...
