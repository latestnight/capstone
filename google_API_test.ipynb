# %%
import pandas as pd
import googlemaps
import requests
import time
import json

# %%
gmaps = googlemaps.Client(key='AIzaSyCFE5vqPizwOgd_vvDWWipZnRm2bNlHdAo')

# %%
#not needed i guess

#url = "https://maps.googleapis.com/maps/api/place/textsearch/json?query=grocery%20stores%20in%20Nashville%20Tennessee&key=AIzaSyCFE5vqPizwOgd_vvDWWipZnRm2bNlHdAo"

#payload={}
#headers = {}

#response = requests.request('GET', url, headers=headers, data=payload)

# %%
grocery_stores = []
params1 = {}

endpoint_url1 = "https://maps.googleapis.com/maps/api/place/textsearch/json?query=grocery%20stores%20in%20Nashville%20Tennessee&key=AIzaSyCFE5vqPizwOgd_vvDWWipZnRm2bNlHdAo"
         
res1 = requests.get(endpoint_url1, params = params1)
results1 =  json.loads(res1.content)
grocery_stores.extend(results1['results'])
time.sleep(2)
while "next_page_token" in results1:
     params1['pagetoken'] = results1['next_page_token'],
     res1 = requests.get(endpoint_url1, params = params1)
     results1 = json.loads(res1.content)
     grocery_stores.extend(results1['results'])
     time.sleep(2)

# %%
print(results1)
# Out:
# {'html_attributions': [], 'results': [{'business_status': 'OPERATIONAL', 'formatted_address': '5001 Charlotte Ave, Nashville, TN 37209, United States', 'geometry': {'location': {'lat': 36.1518346, 'lng': -86.8474861}, 'viewport': {'northeast': {'lat': 36.15308092989272, 'lng': -86.84635707010727}, 'southwest': {'lat': 36.15038127010728, 'lng': -86.84905672989272}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png', 'icon_background_color': '#4B96F3', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet', 'name': 'The Turnip Truck - Charlotte Ave', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3713, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115858099896411920196">A Google User</a>'], 'photo_reference': 'Aap_uEApYJzby57gclwpnOLPfafvx_wgo1Ix9-TnKvELfhiyOa3ZN3jEw0tLyaluRkyP_UxKqrn1DgAegs5S3Tjstugrq-5yoadNkzn6ATkhAZIsEnJwqiMGODM_FrNCyQPwZlqYP-I0kqQGwWRwPvFah6TZj6K8r31i0vaY3u1OEwkMEJIt', 'width': 3006}], 'place_id': 'ChIJJ-D-kKZhZIgR2uvlb8jg_4c', 'plus_code': {'compound_code': '5523+P2 Nashville, Tennessee', 'global_code': '868M5523+P2'}, 'rating': 4.7, 'reference': 'ChIJJ-D-kKZhZIgR2uvlb8jg_4c', 'types': ['grocery_or_supermarket', 'food', 'health', 'point_of_interest', 'store', 'establishment'], 'user_ratings_total': 238}, {'business_status': 'OPERATIONAL', 'formatted_address': '143 McGavock Pk, Nashville, TN 37214, United States', 'geometry': {'location': {'lat': 36.1708586, 'lng': -86.6787306}, 'viewport': {'northeast': {'lat': 36.17232252989272, 'lng': -86.67757242010727}, 'southwest': {'lat': 36.16962287010728, 'lng': -86.68027207989272}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png', 'icon_background_color': '#4B96F3', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet', 'name': 'Kroger', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113890435250045612467">sweetsunnydaygirl</a>'], 'photo_reference': 'Aap_uEAqlLTDvAPS2IYKZ3DD21MpSG9MYDMn2XwLdx4LRBOAkZ9eh6SLWDHt-JebrqkWJw2wC8km_PD2TLVXBenvcNF_4HXePMnf_OLedpsLihh5qHrRbUfJBoP0C4Qs8cYK-_eT_U4NGSvQfuOneTCnSVZP1TYpL5x_4aB7ltMHaBDXKXtD', 'width': 4032}], 'place_id': 'ChIJ01nR5XRpZIgR9acvgLYOuAA', 'plus_code': {'compound_code': '58CC+8G Nashville, Tennessee', 'global_code': '868M58CC+8G'}, 'price_level': 2, 'rating': 4, 'reference': 'ChIJ01nR5XRpZIgR9acvgLYOuAA', 'types': ['grocery_or_supermarket', 'food', 'point_of_interest', 'store', 'establishment'], 'user_ratings_total': 887}, {'business_status': 'OPERATIONAL', 'formatted_address': '1401 Fatherland St, Nashville, TN 37206, United States', 'geometry': {'location': {'lat': 36.1739353, 'lng': -86.7459564}, 'viewport': {'northeast': {'lat': 36.17518487989272, 'lng': -86.74462122010729}, 'southwest': {'lat': 36.17248522010727, 'lng': -86.74732087989273}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png', 'icon_background_color': '#4B96F3', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet', 'name': '4 Way Market', 'opening_hours': {'open_now': True}, 'photos': [{'height': 610, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114883753012009402866">A Google User</a>'], 'photo_reference': 'Aap_uEAfvF11ukbudv9V6c9xxK8HF4qrfZvVAGOOOd7yHRcoMimuIJ8mtNycVSTUYMEwzVp4Vc-c-0KmhKm4VSxv_pb2KATrWScw-rJD1Uzf4Ya7A-y1rkIh857RQiNLck3jnPKJ840PGQxyI5UqDoNuCQ4Wd3FtiHID8NAt3kv00dxT5w68', 'width': 1280}], 'place_id': 'ChIJCXauaCtmZIgRYZpTghT1TBE', 'plus_code': {'compound_code': '57F3+HJ Nashville, Tennessee', 'global_code': '868M57F3+HJ'}, 'rating': 4.3, 'reference': 'ChIJCXauaCtmZIgRYZpTghT1TBE', 'types': ['grocery_or_supermarket', 'supermarket', 'food', 'point_of_interest', 'store', 'establishment'], 'user_ratings_total': 93}, {'business_status': 'OPERATIONAL', 'fo ...

# %%
shop_name1 = []
formatted_address1 = []
shop_lat1 = []
shop_lng1 = []

for i in range(len(grocery_stores)):
    shop = grocery_stores[i]

    try:
        shop_name1.append(shop['name'])
    except:
        shop_name1.append('none')

    try:
        formatted_address1.append(shop['formatted_address'])
    except:
        formatted_address1.append('none')

    try:
        shop_lat1.append(shop['geometry']['location']['lat'])
    except:
        shop_lat1.append('none')

    try:
        shop_lng1.append(shop['geometry']['location']['lng'])
    except:
        shop_lng1.append('none')

# %%
df_dict1 = {'shop_name':shop_name1, 'shop_address':formatted_address1, 'shop_lat':shop_lat1, 'shop_lng':shop_lng1}

grocery_stores_df = pd.DataFrame(df_dict1)
#grocery_stores_df['data_zipcode'] = data_zipcode
grocery_stores_df['duplicator'] = grocery_stores_df['shop_name'] + grocery_stores_df['shop_address']

grocery_stores_df.drop_duplicates(['duplicator'], inplace=True)

#all_grocery_stores = all_grocery_stores.append(grocery_stores_df)

# %%
grocery_stores_df
# Out:
#                                             shop_name  \
# 0                                       Piggly Wiggly
# 1                                  Whole Foods Market
# 2                 Publix Super Market at Capitol View
# 3                                              Kroger
# 4                                  Whole Foods Market
# 5                            The Turnip Truck - Gulch
# 6                                        Trader Joe's
# 7                                   Savi Urban Market
# 8                              Resha's Bi-Rite Market
# 9                                      Swett's Market
# 10                                             Kroger
# 11                  The Turnip Truck - East Nashville
# 12                                  Osborne's Bi-Rite
# 13                                             Kroger
# 14                                     Rosie's Market
# 15                                       Trader Joe's
# 16                                   K&S World Market
# 17  Publix Super Market at Hill Center at Nashvill...
# 18                                             Kroger
# 19  Publix Super Market at Hill Center at Belle Meade
# 20                                   Aleksey's Market
# 21                                         Save A Lot
# 22                             Sprouts Farmers Market
# 23                                      Piggly Wiggly
# 24                                             Kroger
# 25                                             Kroger
# 26          World Wide Market International Groceries
# 27                 Fresh & Fresh International Market
# 28               Publix Super Market at The Crossings
# 29                                             Kroger
# 55  SAM'S MARKET2012 Clarksville Pike, Nashville, ...
# 56  Target Grocery26 White Bridge Rd, Nashville, T...
# 57  Wedgehill Market600 Benton Ave, Nashville, TN ...
# 58  International Food Mart2855 Logan St, Nashvill...
# 59  Woodbine Fresh Market3302 Nolensville Pike, Na...

# %%
#restaurants = []
#params2 = {}

#endpoint_url2 = "https://maps.googleapis.com/maps/api/place/textsearch/json?query=fast%20food%20in%20Nashville%20Tennessee&key=AIzaSyCFE5vqPizwOgd_vvDWWipZnRm2bNlHdAo"
         
#res2 = requests.get(endpoint_url2, params = params2)
#results2 =  json.loads(res2.content)
#restaurants.extend(results2['results'])
#time.sleep(2)
#while "next_page_token" in results2:
     #params2['pagetoken'] = results2['next_page_token'],
     #res2 = requests.get(endpoint_url2, params = params2)
     #results2 = json.loads(res2.content)
     #restaurants.extend(results2['results'])
     #time.sleep(2)

# %%
restaurants = []
params2 = {}

endpoint_url2 = 'https://maps.googleapis.com/maps/api/place/textsearch/json?query=nashville+tn&type=restaurant&key=AIzaSyCFE5vqPizwOgd_vvDWWipZnRm2bNlHdAo'
         
res2 = requests.get(endpoint_url2, params = params2)
results2 =  json.loads(res2.content)
restaurants.extend(results2['results'])
time.sleep(2)
while "next_page_token" in results2:
     params2['pagetoken'] = results2['next_page_token'],
     res2 = requests.get(endpoint_url2, params = params2)
     results2 = json.loads(res2.content)
     restaurants.extend(results2['results'])
     time.sleep(2)

# %%
results2
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': '2526 12th Ave S, Nashville, TN 37204, United States',
#    'geometry': {'location': {'lat': 36.1238377, 'lng': -86.7895489},
#     'viewport': {'northeast': {'lat': 36.12510572989273,
#       'lng': -86.78831842010726},
#      'southwest': {'lat': 36.12240607010728, 'lng': -86.79101807989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'bartaco',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1075,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107497794031873180677">bartaco 12 South</a>'],
#      'photo_reference': 'Aap_uEBg74Hq5wHvTji6wIeyyHqQ0k1sxY_P3eqKoRj8rVUH3mypvBqTMhqac-vlEnkqj_bs2QQDcr2VYriAxtPrs9ac-asPF6Tr_t3bcw1gWQIK4HPWGEWNVS1AKoQFFAfQs5tFQ-H98SPYLiU21MzI-SFLfDuLAS46TeNPsndCCzG1qFE3',
#      'width': 1613}],
#    'place_id': 'ChIJve12si9kZIgRk5eH9rElDCU',
#    'plus_code': {'compound_code': '46F6+G5 Nashville, Tennessee',
#     'global_code': '868M46F6+G5'},
#    'price_level': 2,
#    'rating': 4.5,
#    'reference': 'ChIJve12si9kZIgRk5eH9rElDCU',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2338},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '2902 12th Ave S, Nashville, TN 37204, United States',
#    'geometry': {'location': {'lat': 36.1212469, 'lng': -86.790155},
#     'viewport': {'northeast': {'lat': 36.12262012989272,
#       'lng': -86.78893402010726},
#      'southwest': {'lat': 36.11992047010727, 'lng': -86.79163367989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Epice',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3036,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108775782943555243840">Matt Guthrie</a>'],
#      'photo_reference': 'Aap_uED2red6TSYvtWFMGoAUlyUWhPyf1vczThJPsZiV4iPV0veDjeAxCkIzLy3EsjTjY9c5i2W6vBkFoi-ghC1LYsOwNnz5fRldw8AyYw7kbSCRfEK7KbCqaEj0WWAxUNUo-HMWKRq4ysx0h3nKaDElL_w7o7PscnsPOTDPAMfqCZL_Ufgl',
#      'width': 4048}],
#    'place_id': 'ChIJyWNjODBkZIgRvGC7qJq9m-8',
#    'plus_code': {'compound_code': '46C5+FW Nashville, Tennessee',
#     'global_code': '868M46C5+FW'},
#    'price_level': 2,
#    'rating': 4.4,
#    'reference': 'ChIJyWNjODBkZIgRvGC7qJq9m-8',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 478},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '2714 West End Ave, Nashville, TN 37203, United States',
#    'geometry': {'location': {'lat': 36.1454166, 'lng': -86.812325},
#     'viewport': {'northeast': {'lat': 36.14667207989272,
#       'lng': -86.81095162010728},
#      'southwest': {'lat': 36.14397242010727, 'lng': -86.81365127989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': "Newk's Eatery",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112000244017499084492">Warren Burgess</a>'],
#      'photo_reference': 'Aap_uEBWS1tdsEBNN2GwlxsbdeqWO9OZ8Z2Tqb5qyUb081TOtPMEsWXTS7wQ8rZxNOB9Hwv_VrIL478LdsjhfO32irUpnoluYlVavLphDCWlso347h3wCF4_wyMUqPwLXkaW_xrynNp7EVuQQcEYir3Uwkr9vVjS0ie6JTI8rh8wDEwCrwhP',
#      'width': 4032}],
#    'place_id': 'ChIJe8DbBbBmZIgRW6mSBs-0kTs',
#    'plus_code': {'compound_code': '45WQ+53 Nashville, Tennessee',
#     'global_code': '868M45WQ+53'},
#    'price_level': 2,
#    'rating': 4.4,
#    'reference': 'ChIJe8DbBbBmZIgRW6mSBs-0kTs',
#    'types': ['restaurant',
#     'meal_takeaway',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 933},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '1416 4th Ave N, Nashville, TN 37208, United States',
#    'geometry': {'location': {'lat': 36.1797736, 'lng': -86.78915479999999},
#     'viewport': {'northeast': {'lat': 36.18119162989272,
#       'lng': -86.78789592010726},
#      'southwest': {'lat': 36.17849197010727, 'lng': -86.79059557989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Butchertown Hall',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115756740533380430423">Butchertown Hall</a>'],
#      'photo_reference': 'Aap_uEAt991TqkfgSit4lIfQpWrJQmhamtedVuF-0izkdTX0KJrh6eLYqngoehLGYVPlhBTadWPSzPS_XKgtR6eXmNJvQaHDYJaqa4WIq-JxLRGpG8m780lH1AjTykIWr5TM2gbzoHdO3tO3obTH8J2xM2YJ210MY-o7qYouS7SN07gxulpg',
#      'width': 1500}],
#    'place_id': 'ChIJEViNrgNnZIgRSHIhfKR6U-Y',
#    'plus_code': {'compound_code': '56H6+W8 Nashville, Tennessee',
#     'global_code': '868M56H6+W8'},
#    'price_level': 2,
#    'rating': 4.5,
#    'reference': 'ChIJEViNrgNnZIgRSHIhfKR6U-Y',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1658},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '118 7th Ave N, Nashville, TN 37203, United States',
#    'geometry': {'location': {'lat': 36.1604068, 'lng': -86.7813779},
#     'viewport': {'northeast': {'lat': 36.16169092989272,
#       'lng': -86.7800495701073},
#      'southwest': {'lat': 36.15899127010728, 'lng': -86.78274922989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'TENN',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 5108,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103685998221623193363">A Google User</a>'],
#      'photo_reference': 'Aap_uEC-Jkny0n4kQjwgf04BkahgSjCdybsaQcMoTLkN5ZWwvu3NHpquMhvMs8sxo0jeizg3sctwZ9cCWRuh9AyE3kXHBRefVrsOrY9_QJk7SOCUJ3YoC3Qc03Hl7gz4TXTCMxbLosMNi4-45hUctq602pijBQREf6o4tPZYqm0tRw9NeK4o',
#      'width': 7710}],
#    'place_id': 'ChIJJ0XJjV9nZIgRIbrGPHI2PKE',
#    'plus_code': {'compound_code': '5669+5C Nashville, Tennessee',
#     'global_code': '868M5669+5C'},
#    'rating': 4.3,
#    'reference': 'ChIJJ0XJjV9nZIgRIbrGPHI2PKE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 76},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '1827 12th Ave S, Nashville, TN 37203, United States',
#    'geometry': {'location': {'lat': 36.135071, 'lng': -86.789329},
#     'viewport': {'northeast': {'lat': 36.13644542989271,
#       'lng': -86.78779847010728},
#      'southwest': {'lat': 36.13374577010727, 'lng': -86.79049812989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'The Cookery',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112608054919031188127">Bruce Smith</a>'],
#      'photo_reference': 'Aap_uECO_7k7fVUqK7E1bujjq51BKFmAsqfl9NNIqqeUdpjjPLBOWMzTX2-E0SFMdtbJHa4Ptmh1oCbOAPEsmXR8-KNxc_hLi27g8ygmAGRsn4Plxdz6YQ9_zJxF6GAs3dnaN-PFNhjl4YD3BCNdHAUH6Zhyk_wgahaqVQpCcFYlQ20XKSb0',
#      'width': 4032}],
#    'place_id': 'ChIJ0dvSXYJmZIgR0IJjCA5Xri4',
#    'plus_code': {'compound_code': '46P6+27 Nashville, Tennessee',
#     'global_code': '868M46P6+27'},
#    'price_level': 1,
#    'rating': 4.7,
#    'reference': 'ChIJ0dvSXYJmZIgR0IJjCA5Xri4',
#    'types': ['cafe',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 289},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '2412 Elliston Pl, Nashville, TN 37203, United States',
#    'geometry': {'location': {'lat': 36.1483038, 'lng': -86.8080231},
#     'viewport': {'northeast': {'lat': 36.14962092989273,
#       'lng': -86.80669167010728},
#      'southwest': {'lat': 36.14692127010728, 'lng': -86.80939132989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Thai Satay',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3456,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106432395918658215424">Gordon</a>'],
#      'photo_reference': 'Aap_uECMZQRXdcFYl-QTRuJd3BCQcUp4c3KND3ukp-IRbUNCtymJL8nJmdR-0Xl1JKsUy3XZqRwbjeb0Cw_6ACwGcRS5ZR14kyZFu4kl79nDX7FRjChjwOIEL13ZmkTVapbw5gVeHmeJtz9hghazNelwkNZUUPc1WF9vGh3l1tZTBpRqhZyj',
#      'width': 4608}],
#    'place_id': 'ChIJkzSLjrtmZIgRzYBagJr5dpQ',
#    'plus_code': {'compound_code': '45XR+8Q Nashville, Tennessee',
#     'global_code': '868M45XR+8Q'},
#    'price_level': 1,
#    'rating': 4.4,
#    'reference': 'ChIJkzSLjrtmZIgRzYBagJr5dpQ',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 312},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '2912 West End Ave, Nashville, TN 37203, United States',
#    'geometry': {'location': {'lat': 36.144508, 'lng': -86.813799},
#     'viewport': {'northeast': {'lat': 36.14572647989273,
#       'lng': -86.81232487010728},
#      'southwest': {'lat': 36.14302682010729, 'lng': -86.81502452989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Bombay Palace',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104491507525266044005">Michael Pearson</a>'],
#      'photo_reference': 'Aap_uEBgPAOTbvFQtUKgfdqmuZHIMea9XgssQ6sl6n3Loiv2i5cKjlI7R8s4jfsUH3U0ixiHL2I6olFSe_x6J8K-1Ak95TzslA1P6JldwrY17Khxc3KOgofe3xhjWEs36T-SAun2bD96ac4ZzMyMu9qD1PU-hzewDT2Ya-dGnP5-pS663J2q',
#      'width': 4032}],
#    'place_id': 'ChIJYeyy269mZIgRQsSzPd4b6MQ',
#    'plus_code': {'compound_code': '45VP+RF Nashville, Tennessee',
#     'global_code': '868M45VP+RF'},
#    'price_level': 2,
#    'rating': 4.3,
#    'reference': 'ChIJYeyy269mZIgRQsSzPd4b6MQ',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 950},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '214 11th Ave S, Nashville, TN 37203, United States',
#    'geometry': {'location': {'lat': 36.1547229, 'lng': -86.78455389999999},
#     'viewport': {'northeast': {'lat': 36.15607242989272,
#       'lng': -86.78339627010727},
#      'southwest': {'lat': 36.15337277010728, 'lng': -86.78609592989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Milk & Honey Gulch',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2184,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117125506248020649052">Jamie McKerral</a>'],
#      'photo_reference': 'Aap_uEAgn2eyijZl2eyDIcTVa3S12Ck0F_KBlUPUjnNq3MC5mNENpeOufK1qzWI9CuljCksc9QazECgcvYLiCdZjuX83zcdRVFPWjlAMu8Ca5mzI9mNr2OQHchT4lGPyNz8UGafL9sagRss415Yi6jxR9CgloCfoCuNe_iLqXSC7Ra29j1vS',
#      'width': 4608}],
#    'place_id': 'ChIJCUldzfRmZIgRTdc-qk-jhFo',
#    'plus_code': {'compound_code': '5638+V5 Nashville, Tennessee',
#     'global_code': '868M5638+V5'},
#    'price_level': 2,
#    'rating': 4.4,
#    'reference': 'ChIJCUldzfRmZIgRTdc-qk-jhFo',
#    'types': ['cafe',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 2000},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '3790 Bedford Ave, Nashville, TN 37215, United States',
#    'geometry': {'location': {'lat': 36.1097755, 'lng': -86.81940139999999},
#     'viewport': {'northeast': {'lat': 36.11114742989271,
#       'lng': -86.81811497010727},
#      'southwest': {'lat': 36.10844777010727, 'lng': -86.82081462989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'etc. restaurant',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2400,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112566019636590409148">etc Restaurant</a>'],
#      'photo_reference': 'Aap_uEDSQrrfuvJZrsR-F9nttWosIX6F9lmBEIz8PDwsubjEmwHm5tgL0ch-GmA90eNe882zn3eEk2i75ok3zllG_eNKQ1V1BW32S9iVIAHbUwl9JW6FJZJD-9mXFH9wNPvuvEUJECEXO7dsPes6oAStNU_8IfyK86x6eHrMbeiPvazkejqi',
#      'width': 3600}],
#    'place_id': 'ChIJ0VfK_3RkZIgR8XizdXN3UOM',
#    'plus_code': {'compound_code': '455J+W6 Nashville, Tennessee',
#     'global_code': '868M455J+W6'},
#    'price_level': 3,
#    'rating': 4.7,
#    'reference': 'ChIJ0VfK_3RkZIgR8XizdXN3UOM',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 369},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '2121 Belcourt Ave, Nashville, TN 37212, United States',
#    'geometry': {'location': {'lat': 36.1365575, 'lng': -86.8027608},
#     'viewport': {'northeast': {'lat': 36.13803582989273,
#       'lng': -86.80137862010727},
#      'southwest': {'lat': 36.13533617010728, 'lng': -86.80407827989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Meet Noodles',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2736,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116860005164229784095">A Google User</a>'],
#      'photo_reference': 'Aap_uEBFDxuWvqvuRqIG7LRuVoHXzzksMBn-G3gUpRx6YVRHIjttm-Dun5W4OOAjaX0dwnRDMpPxd8fDDq0RyXOw0N2sKAui5gML-1-GBzN_o0UdNM8w_VMLCxS9GMCI1Cp4RkpB9af-i2ybrSaHjmtGBUxZwhLwQS-ag_IcNxTZ4671EhBj',
#      'width': 3648}],
#    'place_id': 'ChIJPcfCr2FnZIgRTnbg4rwWWkg',
#    'plus_code': {'compound_code': '45PW+JV Nashville, Tennessee',
#     'global_code': '868M45PW+JV'},
#    'price_level': 2,
#    'rating': 4.5,
#    'reference': 'ChIJPcfCr2FnZIgRTnbg4rwWWkg',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 410},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '2421 Vanderbilt Pl, Nashville, TN 37212, United States',
#    'geometry': {'location': {'lat': 36.1448561, 'lng': -86.80648819999999},
#     'viewport': {'northeast': {'lat': 36.14626432989272,
#       'lng': -86.80518147010727},
#      'southwest': {'lat': 36.14356467010728, 'lng': -86.80788112989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Grins Vegetarian Cafe',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106344170887148742852">Sarin Murlidar</a>'],
#      'photo_reference': 'Aap_uEDonBijdmljnBRCHo8wjokPX7BUtC1R8pfyjyqVuuUaekA83NbmBmSSKqQbNuoCNSknNG59kx29OrqDRQYW52tWN9oyFM_kn9Quhceu6KxNbT3YXmnuK5gat72D_RijKQ2mu-HY58eorWGBf0M2a6sO29emGWCeT1MMDEG2pTxnOS4E',
#      'width': 4000}],
#    'place_id': 'ChIJx5IQrbxmZIgRVkbYMutkb98',
#    'plus_code': {'compound_code': '45VV+WC Nashville, Tennessee',
#     'global_code': '868M45VV+WC'},
#    'rating': 4.2,
#    'reference': 'ChIJx5IQrbxmZIgRVkbYMutkb98',
#    'types': ['restaurant',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 99},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '1201 Demonbreun St Suite 104, Nashville, TN 37203, United States',
#    'geometry': {'location': {'lat': 36.154392, 'lng': -86.7863151},
#     'viewport': {'northeast': {'lat': 36.15574932989272,
#       'lng': -86.78483442010729},
#      'southwest': {'lat': 36.15304967010728, 'lng': -86.78753407989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': "Del Frisco's Grille",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 720,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103876859464899340453">Del Frisco&#39;s Grille</a>'],
#      'photo_reference': 'Aap_uEBbI34rcMmFAweuR5wROy2gFgsWu7tkEua8xxXxJTa6yYYqPKeaJOSSI51NRK_665cMUbbq7O2PDEaskYL2UxSkaeNBGiUHcMGRiiQ-8_oW3taCqiWriG13gV1KDbH7YCfSaV_6mDyxLZPoMo1VWu024dG67Ybutg21nREf7tt6pvTh',
#      'width': 720}],
#    'place_id': 'ChIJp-gQTotmZIgRz9RAL0guga4',
#    'plus_code': {'compound_code': '5637+QF Nashville, Tennessee',
#     'global_code': '868M5637+QF'},
#    'price_level': 3,
#    'rating': 4.3,
#    'reference': 'ChIJp-gQTotmZIgRz9RAL0guga4',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 911},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '322 Broadway, Nashville, TN 37201, United States',
#    'geometry': {'location': {'lat': 36.1612257, 'lng': -86.77716629999999},
#     'viewport': {'northeast': {'lat': 36.16250827989272,
#       'lng': -86.77580252010728},
#      'southwest': {'lat': 36.15980862010728, 'lng': -86.77850217989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Margaritaville Restaurant - Nashville',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3264,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106537889594261620058">Margaritaville</a>'],
#      'photo_reference': 'Aap_uEDavlkMOksSR-rQKcADK8mHeyIBK9CQzbQhc5wVN-Sm_tx2KXwlWeYNSs0LNJSSzfy5Mv25a1UI69Xqoz-hExmC-Sc8yoO57AdJscdS3xoljxoltrlc4whqFh5-fWE-HTd5FnEWvRzAUyo2Sdz-UzZKz4OKOZexxBxYH3IOnl_qvwy0',
#      'width': 4928}],
#    'place_id': 'ChIJM43Q5ltmZIgRLh4H1APwfhc',
#    'plus_code': {'compound_code': '566F+F4 Nashville, Tennessee',
#     'global_code': '868M566F+F4'},
#    'price_level': 2,
#    'rating': 4.1,
#    'reference': 'ChIJM43Q5ltmZIgRLh4H1APwfhc',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 3996},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '250 Rep. John Lewis Way S, Nashville, TN 37203, United States',
#    'geometry': {'location': {'lat': 36.157178, 'lng': -86.77531599999999},
#     'viewport': {'northeast': {'lat': 36.15859477989272,
#       'lng': -86.77368002010728},
#      'southwest': {'lat': 36.15589512010728, 'lng': -86.77637967989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Kitchen Notes',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2135,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101521601409055701944">Kitchen Notes</a>'],
#      'photo_reference': 'Aap_uEDmA36xusAgqOFrTUJqFydNWebuU0O3ejswIE-mG6KgeCZAFJDxSmBoHhoQxtczqtAddGDH_9NFa5pDgTaSvkh3WYzRFLWtDZE6G2ebHythQDmz9CYtVFOYcyYY0Jt2OsQ69ol_DC-4Ongp_V2-SPHZbnPsssQY_rEcGbmmL_zGpFUk',
#      'width': 2863}],
#    'place_id': 'ChIJ5aqfgl5mZIgRba1uPZIAu1Q',
#    'plus_code': {'compound_code': '564F+VV Nashville, Tennessee',
#     'global_code': '868M564F+VV'},
#    'price_level': 2,
#    'rating': 4.3,
#    'reference': 'ChIJ5aqfgl5mZIgRba1uPZIAu1Q',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 444},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '1001 Broadway (Restaurant in Hotel, Lobby, Nashville, TN 37203, United States',
#    'geometry': {'location': {'lat': 36.1572582, 'lng': -86.7847572},
#     'viewport': {'northeast': {'lat': 36.15870172989272,
#       'lng': -86.78320722010726},
#      'southwest': {'lat': 36.15600207010728, 'lng': -86.7859068798927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Stationairy',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3047,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103780926908292051485">Jonathan McKinney</a>'],
#      'photo_reference': 'Aap_uEBrvZmL0s6L8Bd33KaBhhhu-G0Cd7fzSSoCinUbBIDJmZmjcfsesIai75_MY6Xy9MEi5GxnMrhwasOEKXhsOqsCUpF-NZooaxqVHlyCqA3DMSpZvFW1Sw4AZjJVspY7_cvim1OGT99yBmURxSRFVQVhsRs_NVWlXn0H7byIBSGVpiUN',
#      'width': 3792}],
#    'place_id': 'ChIJdySnNMpnZIgRc6fAsrxJGjE',
#    'plus_code': {'compound_code': '5648+W3 Nashville, Tennessee',
#     'global_code': '868M5648+W3'},
#    'rating': 4.3,
#    'reference': 'ChIJdySnNMpnZIgRc6fAsrxJGjE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 38},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '201 1st Ave S, Nashville, TN 37201, United States',
#    'geometry': {'location': {'lat': 36.1599591, 'lng': -86.7732544},
#     'viewport': {'northeast': {'lat': 36.16136647989272,
#       'lng': -86.77177652010728},
#      'southwest': {'lat': 36.15866682010728, 'lng': -86.77447617989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'The Hampton Social - Nashville',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 5304,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103373804951490048854">Derek Lee</a>'],
#      'photo_reference': 'Aap_uECVrmFpQFXa7NFiR6P6DNv2XCayMzriOlqEqbmEqMS-ZNeDNDCtLwgfYKGunhAqkhegOq1GUrQAkgL9CoX1hNTMx_uch_fumdRsmOFZHIgpECQxCvW-6hH1XU8Y_KyJaJnPn1PDkpsxMgWba64I_lI6GtEnwqYlV9cBdHUAJxHpwl_y',
#      'width': 7952}],
#    'place_id': 'ChIJ2zNcAORnZIgRDegDF_fkiW0',
#    'plus_code': {'compound_code': '565G+XM Nashville, Tennessee',
#     'global_code': '868M565G+XM'},
#    'rating': 4.4,
#    'reference': 'ChIJ2zNcAORnZIgRDegDF_fkiW0',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 949},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '1000 Broadway, Nashville, TN 37203, United States',
#    'geometry': {'location': {'lat': 36.1580962, 'lng': -86.78496109999999},
#     'viewport': {'northeast': {'lat': 36.15966252989272,
#       'lng': -86.78339477010728},
#      'southwest': {'lat': 36.15696287010728, 'lng': -86.78609442989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'The Nashville Grange',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1600,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110270351057429660629">A Google User</a>'],
#      'photo_reference': 'Aap_uEBhfAqsTm2kTT5IvYP8uK_U_UMRt9vij-_2oXgEWXaPZjVjzU0r15g2sTt53tmo2gAtWtARLbR_yUTZyFXJmC233cnhddJ7lSlUl6RD-3EV90Z08_6I9bFO5AR-nXveybAG59r9Qu9zQFYojDzeDQmtpLdThl4Oeyq-pRgu8CWq9Kiv',
#      'width': 2400}],
#    'place_id': 'ChIJ0Za5XkhnZIgRFw_fG2gECGM',
#    'plus_code': {'compound_code': '5658+62 Nashville, Tennessee',
#     'global_code': '868M5658+62'},
#    'rating': 4.3,
#    'reference': 'ChIJ0Za5XkhnZIgRFw_fG2gECGM',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 37},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '417 Union St, Nashville, TN 37219, United States',
#    'geometry': {'location': {'lat': 36.1645791, 'lng': -86.7803802},
#     'viewport': {'northeast': {'lat': 36.16602267989271,
#       'lng': -86.77909347010727},
#      'southwest': {'lat': 36.16332302010727, 'lng': -86.78179312989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': '417 Union',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 528,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108527133901572952158">417 Union</a>'],
#      'photo_reference': 'Aap_uECzvywu9Pv3dTVOki7m21HszeTaXb5jWF-TVYJUv36_uLlE4W9Po54nXNPXoZqPtV5TxlC9dhSupfTAZBIPhSBFq4PyrGuBrLWmsRpC23PI1PDZR_Dothb_03Yz1N4YVV_zW32BcZ8mB9D1RAr9d3WGVhTNe6gUrFHvdDM0ndbA_8Lu',
#      'width': 1264}],
#    'place_id': 'ChIJxYzaO1hmZIgROwZYPkIWqpI',
#    'plus_code': {'compound_code': '5679+RR Nashville, Tennessee',
#     'global_code': '868M5679+RR'},
#    'price_level': 2,
#    'rating': 4.5,
#    'reference': 'ChIJxYzaO1hmZIgROwZYPkIWqpI',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 937},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '1120 McGavock St, Nashville, TN 37203, United States',
#    'geometry': {'location': {'lat': 36.1560807, 'lng': -86.7862808},
#     'viewport': {'northeast': {'lat': 36.15729102989271,
#       'lng': -86.78489922010728},
#      'southwest': {'lat': 36.15459137010727, 'lng': -86.78759887989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Saint Añejo',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1333,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115354418982987669002">Saint Añejo</a>'],
#      'photo_reference': 'Aap_uEARWdtyhD-OfzCDZXKYUW1we9FJm5ceb4-xCWYCrnKoo7PAMPUPPFo8TMH4rolxgJfca5VDnnSDMWoAH229xMrkb3JMygKwZag0gEgiRPR6uc9iUEpQNX8SxbCMnoEXKcpZ_fHbgDi-wg05KQ8RtaUccVJUtNxZgJsSZz4bqQU7-hof',
#      'width': 2000}],
#    'place_id': 'ChIJc87PvPRmZIgRyIDOhbP1pmM',
#    'plus_code': {'compound_code': '5647+CF Nashville, Tennessee',
#     'global_code': '868M5647+CF'},
#    'price_level': 2,
#    'rating': 4.3,
#    'reference': 'ChIJc87PvPRmZIgRyIDOhbP1pmM',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1860}],
#  'status': 'OK'}

# %%
shop_name2 = []
formatted_address2 = []
shop_lat2 = []
shop_lng2 = []

for i in range(len(restaurants)):
    shop2 = restaurants[i]

    try:
        shop_name2.append(shop['name'])
    except:
        shop_name2.append('none')

    try:
        formatted_address2.append(shop['formatted_address'])
    except:
        formatted_address2.append('none')

    try:
        shop_lat2.append(shop['geometry']['location']['lat'])
    except:
        shop_lat2.append('none')

    try:
        shop_lng2.append(shop['geometry']['location']['lng'])
    except:
        shop_lng2.append('none')

# %%
df_dict2 = {'shop_name':shop_name2, 'shop_address':formatted_address2, 'shop_lat':shop_lat2, 'shop_lng':shop_lng2}

restaurants_df = pd.DataFrame(df_dict2)
#grocery_stores_df['data_zipcode'] = data_zipcode
restaurants_df['duplicator'] = restaurants_df['shop_name'] + restaurants_df['shop_address']

restaurants_df.drop_duplicates(['duplicator'], inplace=True)

#all_grocery_stores = all_grocery_stores.append(grocery_stores_df)

# %%
restaurants_df.shape
# Out:
# (1, 5)
