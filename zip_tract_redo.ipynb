# %%
import pandas as pd

# %%
# list of municipal nashville zipcodes that i am using for my project

nashzips = pd.read_excel('/Users/k.simmons/Desktop/NSS/data analytics bootcamp/capstone/Data/nashzipcodes.xlsx')
ziplist = nashzips['zip'].to_list()
ziplist
# Out:
# [37216,
#  37204,
#  37221,
#  37212,
#  37209,
#  37206,
#  37217,
#  37219,
#  37218,
#  37232,
#  37213,
#  37205,
#  37203,
#  37201,
#  37214,
#  37240,
#  37208,
#  37207,
#  37215,
#  37228,
#  37210,
#  37211,
#  37220]

# %%
# importing my nashville disease data

nashdisease2016 = pd.read_csv('/Users/k.simmons/Desktop/NSS/data analytics bootcamp/capstone/Data/CDC data/CSVs/nashdisease2016.csv')
nashdisease2017 = pd.read_csv('/Users/k.simmons/Desktop/NSS/data analytics bootcamp/capstone/Data/CDC data/CSVs/nashdisease2017.csv')
nashdisease2018 = pd.read_csv('/Users/k.simmons/Desktop/NSS/data analytics bootcamp/capstone/Data/CDC data/CSVs/fixednashdisease2018.csv')
nashdisease2019 = pd.read_csv('/Users/k.simmons/Desktop/NSS/data analytics bootcamp/capstone/Data/CDC data/CSVs/nashdisease2019.csv')

# %%
# importing the HUD crosswalk tract to zip data

tractzip16 = pd.read_excel('/Users/k.simmons/Desktop/NSS/data analytics bootcamp/capstone/Data/crosswalk files/TRACT_ZIP_032016.xlsx')
tractzip17 = pd.read_excel('/Users/k.simmons/Desktop/NSS/data analytics bootcamp/capstone/Data/crosswalk files/TRACT_ZIP_032017.xlsx')
tractzip18 = pd.read_excel('/Users/k.simmons/Desktop/NSS/data analytics bootcamp/capstone/Data/crosswalk files/TRACT_ZIP_032018.xlsx')
tractzip19 = pd.read_excel('/Users/k.simmons/Desktop/NSS/data analytics bootcamp/capstone/Data/crosswalk files/TRACT_ZIP_032019.xlsx')

# %%
nashdisease2016.head(2)
# Out:
#    Unnamed: 0 StateAbbr  PlaceName  PlaceFIPS    TractFIPS  \
# 0       22333        TN  Nashville    4752006  47037014400
# 1       22334        TN  Nashville    4752006  47037010801
#
#          Place_TractID  Population2010  ACCESS2_CrudePrev ACCESS2_Crude95CI  \
# 0  4752006-47037014400            1250               26.7      (22.4, 30.8)
# 1  4752006-47037010801            5363               19.7      (17.3, 22.1)
#
#    ARTHRITIS_CrudePrev  ... PAPTEST_Crude95CI  PHLTH_CrudePrev  \
# 0                 27.5  ...      (76.9, 82.4)             18.6
# 1                 28.0  ...      (81.5, 85.1)             15.3
#
#   PHLTH_Crude95CI  SLEEP_CrudePrev SLEEP_Crude95CI  STROKE_CrudePrev  \
# 0    (16.7, 20.6)             45.2    (43.3, 47.0)               4.6
# 1    (14.1, 16.6)             38.7    (37.3, 39.9)               3.4
#
#   STROKE_Crude95CI  TEETHLOST_CrudePrev TEETHLOST_Crude95CI  \
# 0     ( 4.1,  5.1)                 31.9        (22.3, 41.2)
# 1     ( 3.1,  3.7)                 21.4        (15.4, 28.3)
#
#                      Geolocation
# 0  36.1576629645, -86.8057331508
# 1  36.2758406196, -86.7227516725
#
# [2 rows x 64 columns]

# %%
# creating filter for census tracts that are only found in the disease data

tractmask = nashdisease2016['TractFIPS'].to_list()

# %%
# filtering tractzip16 to only show the tracts that are found in the disease data

diseasetracts16 = tractzip16['TRACT'].isin(tractmask)
nashtractzip16 = tractzip16[diseasetracts16]
nashtractzip16.head(2)
# Out:
#               TRACT    ZIP  RES_RATIO  BUS_RATIO  OTH_RATIO  TOT_RATIO
# 134840  47037010103  37072   0.254545        0.0        0.0   0.252133
# 134841  47037010103  37080   0.715789        1.0        0.0   0.718483

# %%
# now that tractzip16 contains only revelant tracts, filtering further to only include zips from ziplist

zipfilter16 = nashtractzip16['ZIP'].isin(ziplist)
nashtractzip16 = nashtractzip16[zipfilter16]
nashtractzip16.head(2)
# Out:
#               TRACT    ZIP  RES_RATIO  BUS_RATIO  OTH_RATIO  TOT_RATIO
# 134847  47037010105  37218   0.807269   0.437500        0.0   0.800000
# 134849  47037010106  37207   0.489756   0.771429        0.0   0.499057

# %%
#dropping unnecessary columns

nashtractzip16 = nashtractzip16.drop(['RES_RATIO', 'BUS_RATIO', 'OTH_RATIO', 'TOT_RATIO'], axis=1)
nashtractzip16.head(2)
# Out:
#               TRACT    ZIP
# 134847  47037010105  37218
# 134849  47037010106  37207

# %%
#resetting index, and then setting tract number to index for ease of making dictionary using .to_dict()

