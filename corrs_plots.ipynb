# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
nashdisease2019 = pd.read_csv('/Users/k.simmons/Desktop/NSS/data analytics bootcamp/capstone/Data/CDC data/CDC fixed relationships/nashdisease19.csv')
fixeddtype_groceries = pd.read_csv('/Users/k.simmons/Desktop/NSS/data analytics bootcamp/capstone/Data/fixeddtype_groceries.csv')

# %%
nashdisease2019 = nashdisease2019.drop(columns = 'Unnamed: 0')
nashdisease2019
# Out:
#     StateAbbr  PlaceName  PlaceFIPS    TractFIPS        Place_TractID  \
# 0          TN  Nashville    4752006  47037010105  4752006-47037010105
# 1          TN  Nashville    4752006  47037010106  4752006-47037010106
# 2          TN  Nashville    4752006  47037010106  4752006-47037010106
# 3          TN  Nashville    4752006  47037010201  4752006-47037010201
# 4          TN  Nashville    4752006  47037010702  4752006-47037010702
# ..        ...        ...        ...          ...                  ...
# 205        TN  Nashville    4752006  47037019500  4752006-47037019500
# 206        TN  Nashville    4752006  47037019500  4752006-47037019500
# 207        TN  Nashville    4752006  47037019500  4752006-47037019500
# 208        TN  Nashville    4752006  47037019500  4752006-47037019500
# 209        TN  Nashville    4752006  47037019600  4752006-47037019600
#
#      Population2010  ACCESS2_CrudePrev ACCESS2_Crude95CI  ARTHRITIS_CrudePrev  \
# ...

# %%
fixeddtype_groceries = fixeddtype_groceries.drop(columns = 'Unnamed: 0')

# %%
fixeddtype_groceries = fixeddtype_groceries.drop(index=46)

# %%
myzips = ['37216',
 '37204',
 '37221',
 '37212',
 '37209',
 '37206',
 '37217',
 '37219',
 '37218',
 '37232',
 '37213',
 '37205',
 '37203',
 '37201',
 '37214',
 '37240',
 '37208',
 '37207',
 '37215',
 '37228',
 '37210',
 '37211',
 '37220']

# %%
fixeddtype_groceries['shop_address'].nunique()
# Out:
# 256

# %%
fixeddtype_groceries
# Out:
#                   shop_name                                shop_address  \
# 0                      ALDI       615 Gallatin Ave, Nashville, TN 37206
# 1                      ALDI     135 S. Gallatin Pike, Madison, TN 37115
# 2                      ALDI        405 American Rd, Nashville, TN 37209
# 3                      ALDI  3758 Nolensville Pike, Nashville, TN 37211
# 4                      ALDI          7035 Hwy 70 S, Nashville, TN 37221
# ..                      ...                                         ...
# 252      Whole Foods Market   6730 Papermill Dr NW, Knoxville, TN 37919
# 253          Swett's Market         702 28th Ave N, Nashville, TN 37208
# 254        Aleksey's Market        718 Thompson Ln, Nashville, TN 37204
# 255  Sprouts Farmers Market          7620 Hwy 70 S, Nashville, TN 37221
# 256      Whole Foods Market            7825 US-72, Germantown, TN 38138
#
#       shop_lat   shop_lng                                              types  \
# ...

# %%
zipmaskfinal = fixeddtype_groceries['zip_code'].isin([myzips])

# %%
fixeddtype_groceries[zipmaskfinal]
# Out:
# Empty DataFrame
# Columns: [shop_name, shop_address, shop_lat, shop_lng, types, zip_code]
# Index: []

# %%
mask37211= fixeddtype_groceries['zip_code'].isin([37211])

# %%
fixeddtype_groceries[mask37211]
# Out:
#     shop_name                                 shop_address   shop_lat  \
# 3        ALDI   3758 Nolensville Pike, Nashville, TN 37211  36.090287
# 18    Bi-Rite   3302 Nolensville Pike, Nashville, TN 37211  36.101451
# 53     Kroger        61 E Thompson Ln, Nashville, TN 37211  36.109818
# 55     Kroger   5771 Nolensville Road, Nashville, TN 37211  36.046395
# 56     Kroger     5713 Edmondson Pike, Nashville, TN 37211  36.039181
# 133    Publix  15544 Old Hickory Blvd, Nashville, TN 37211  36.041027
# 191   Walmart     5531 Edmondson Pike, Nashville, TN 37211  36.042193
# 222   Walmart   4040 Nolensville Pike, Nashville, TN 37211  36.082472
# 229   Walmart   5824 Nolensville Pike, Nashville, TN 37211  36.041942
#
#       shop_lng                                              types  zip_code
# 3   -86.732314  ['supermarket', 'grocery_or_supermarket', 'foo...     37211
# 18  -86.740120  ['grocery_or_supermarket', 'supermarket', 'foo...     37211
# ...

# %%
['37216',
 '37204',
 '37221',
 '37212',
 '37209',
 '37206',
 '37217',
 '37219',
 '37218',
 '37232',
 '37213',
 '37205',
 '37203',
 '37201',
 '37214',
 '37240',
 '37208',
 '37207',
 '37215',
 '37228',
 '37210',
 '37211',
 '37220']
# Out:
# ['37216',
#  '37204',
#  '37221',
#  '37212',
#  '37209',
#  '37206',
#  '37217',
#  '37219',
#  '37218',
#  '37232',
#  '37213',
#  '37205',
#  '37203',
#  '37201',
#  '37214',
#  '37240',
#  '37208',
#  '37207',
#  '37215',
#  '37228',
#  '37210',
#  '37211',
#  '37220']

# %%
fixeddtype_groceries['zip_code']
# Out:
# 0      37206
# 1      37115
# 2      37209
# 3      37211
# 4      37221
#        ...
# 252    37919
# 253    37208
# 254    37204
# 255    37221
# 256    38138
# Name: zip_code, Length: 256, dtype: int64

# %%
zip_count = fixeddtype_groceries['zip_code'].value_counts()

# %%
zip_count = pd.DataFrame(zip_count)

# %%
zip_count
# Out:
#        zip_code
# 37209         9
# 37211         9
# 37066         9
# 37027         8
# 37064         8
# ...         ...
# 38585         1
# 37033         1
# 38464         1
# 37179         1
# 38138         1
#
# [84 rows x 1 columns]

# %%
nashdisease2019.columns
# Out:
# Index(['StateAbbr', 'PlaceName', 'PlaceFIPS', 'TractFIPS', 'Place_TractID',
#        'Population2010', 'ACCESS2_CrudePrev', 'ACCESS2_Crude95CI',
#        'ARTHRITIS_CrudePrev', 'ARTHRITIS_Crude95CI', 'BINGE_CrudePrev',
#        'BINGE_Crude95CI', 'BPHIGH_CrudePrev', 'BPHIGH_Crude95CI',
#        'BPMED_CrudePrev', 'BPMED_Crude95CI', 'CANCER_CrudePrev',
#        'CANCER_Crude95CI', 'CASTHMA_CrudePrev', 'CASTHMA_Crude95CI',
#        'CHD_CrudePrev', 'CHD_Crude95CI', 'CHECKUP_CrudePrev',
#        'CHECKUP_Crude95CI', 'CHOLSCREEN_CrudePrev', 'CHOLSCREEN_Crude95CI',
#        'COLON_SCREEN_CrudePrev', 'COLON_SCREEN_Crude95CI', 'COPD_CrudePrev',
#        'COPD_Crude95CI', 'COREM_CrudePrev', 'COREM_Crude95CI',
#        'COREW_CrudePrev', 'COREW_Crude95CI', 'CSMOKING_CrudePrev',
#        'CSMOKING_Crude95CI', 'DENTAL_CrudePrev', 'DENTAL_Crude95CI',
#        'DIABETES_CrudePrev', 'DIABETES_Crude95CI', 'HIGHCHOL_CrudePrev',
#        'HIGHCHOL_Crude95CI', 'KIDNEY_CrudePrev', 'KIDNEY_Crude95CI',
# ...

# %%
cols = ['BPHIGH_CrudePrev',
'CHD_CrudePrev',
'DIABETES_CrudePrev',
'HIGHCHOL_CrudePrev',
'OBESITY_CrudePrev',
'STROKE_CrudePrev',
'zipunpacked'
]

# %%
nashdxcol19 = nashdisease2019[cols]

# %%
nashdxcol19
# Out:
#      BPHIGH_CrudePrev  CHD_CrudePrev  DIABETES_CrudePrev  HIGHCHOL_CrudePrev  \
# 0                47.4            7.0                16.7                36.4
# 1                42.7            6.3                14.1                32.9
# 2                42.7            6.3                14.1                32.9
# 3                39.0            6.3                12.2                34.6
# 4                46.9           11.6                18.7                40.3
# ..                ...            ...                 ...                 ...
# 205              28.3            3.9                 7.9                26.7
# 206              28.3            3.9                 7.9                26.7
# 207              28.3            3.9                 7.9                26.7
# 208              28.3            3.9                 7.9                26.7
# 209              31.6            5.2                 9.2                30.2
#
# ...

# %%
groupedzips = nashdxcol19.groupby('zipunpacked').mean()

# %%
groupedzips
# Out:
#              BPHIGH_CrudePrev  CHD_CrudePrev  DIABETES_CrudePrev  \
# zipunpacked
# 37201               31.700000       4.350000            9.450000
# 37203               30.976923       4.553846           10.261538
# 37204               30.638462       5.169231            9.246154
# 37205               32.066667       5.575000            8.550000
# 37206               34.400000       5.366667           10.944444
# 37207               42.642857       6.864286           15.464286
# 37208               43.637500       6.812500           16.325000
# 37209               33.137500       5.237500           10.143750
# 37210               37.600000       6.972727           13.336364
# 37211               31.814286       5.396429           10.228571
# 37212               22.500000       3.111111            6.111111
# 37213               41.066667       6.833333           14.966667
# 37214               32.628571       5.628571            9.542857
# ...

# %%
groupedzips = groupedzips.merge(zip_count, how= 'left', left_index=True, right_index=True)

# %%
groupedzips
# Out:
#              BPHIGH_CrudePrev  CHD_CrudePrev  DIABETES_CrudePrev  \
# zipunpacked
# 37201               31.700000       4.350000            9.450000
# 37203               30.976923       4.553846           10.261538
# 37204               30.638462       5.169231            9.246154
# 37205               32.066667       5.575000            8.550000
# 37206               34.400000       5.366667           10.944444
# 37207               42.642857       6.864286           15.464286
# 37208               43.637500       6.812500           16.325000
# 37209               33.137500       5.237500           10.143750
# 37210               37.600000       6.972727           13.336364
# 37211               31.814286       5.396429           10.228571
# 37212               22.500000       3.111111            6.111111
# 37213               41.066667       6.833333           14.966667
# 37214               32.628571       5.628571            9.542857
# ...

# %%
groupedzips.loc[groupedzips['zip_code'].isnull(), 'zip_code'] = 0

# %%
usethis = groupedzips.groupby(['zip_code']).mean()

# %%
usethis
# Out:
#           BPHIGH_CrudePrev  CHD_CrudePrev  DIABETES_CrudePrev  \
# zip_code
# 0.0              30.814286       4.967532           10.112338
# 1.0              31.700000       4.350000            9.450000
# 2.0              22.500000       3.111111            6.111111
# 3.0              46.885714       7.800000           17.371429
# 4.0              35.172438       5.688436           11.267135
# 5.0              37.810000       6.770000           12.370000
# 6.0              30.769231       5.120979            8.886713
# 7.0              32.961538       5.053846           10.492308
# 9.0              32.475893       5.316964           10.186161
#
#           HIGHCHOL_CrudePrev  OBESITY_CrudePrev  STROKE_CrudePrev
# zip_code
# 0.0                26.935498          30.480087          3.083117
# 1.0                28.100000          31.350000          2.600000
# 2.0                23.000000          24.066667          1.733333
# ...

# %%
zip_count
# Out:
#        zip_code
# 37209         9
# 37211         9
# 37066         9
# 37027         8
# 37064         8
# ...         ...
# 38585         1
# 37033         1
# 38464         1
# 37179         1
# 38138         1
#
# [84 rows x 1 columns]

# %%
groupedzips.corr()
# Out:
#                     BPHIGH_CrudePrev  CHD_CrudePrev  DIABETES_CrudePrev  \
# BPHIGH_CrudePrev            1.000000       0.974325            0.977633
# CHD_CrudePrev               0.974325       1.000000            0.943508
# DIABETES_CrudePrev          0.977633       0.943508            1.000000
# HIGHCHOL_CrudePrev          0.851735       0.894178            0.734651
# OBESITY_CrudePrev           0.909610       0.838490            0.955396
# STROKE_CrudePrev            0.960880       0.934665            0.995052
# zip_code                    0.113041       0.130815            0.035870
#
#                     HIGHCHOL_CrudePrev  OBESITY_CrudePrev  STROKE_CrudePrev  \
# BPHIGH_CrudePrev              0.851735           0.909610          0.960880
# CHD_CrudePrev                 0.894178           0.838490          0.934665
# DIABETES_CrudePrev            0.734651           0.955396          0.995052
# HIGHCHOL_CrudePrev            1.000000           0.600032          0.698483
# ...

# %%
usethis
# Out:
#           BPHIGH_CrudePrev  CHD_CrudePrev  DIABETES_CrudePrev  \
# zip_code
# 0.0              30.814286       4.967532           10.112338
# 1.0              31.700000       4.350000            9.450000
# 2.0              22.500000       3.111111            6.111111
# 3.0              46.885714       7.800000           17.371429
# 4.0              35.172438       5.688436           11.267135
# 5.0              37.810000       6.770000           12.370000
# 6.0              30.769231       5.120979            8.886713
# 7.0              32.961538       5.053846           10.492308
# 9.0              32.475893       5.316964           10.186161
#
#           HIGHCHOL_CrudePrev  OBESITY_CrudePrev  STROKE_CrudePrev
# zip_code
# 0.0                26.935498          30.480087          3.083117
# 1.0                28.100000          31.350000          2.600000
# 2.0                23.000000          24.066667          1.733333
# ...

# %%
usethis.to_csv('Data/scatterplot_DF.csv')

# %%
sns.scatterplot(data = usethis,
                x = 'zip_code',
                y = 'BPHIGH_CrudePrev',
                );
