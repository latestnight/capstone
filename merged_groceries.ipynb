# %%
import pandas as pd

# %%
aldi = pd.read_csv('/Users/k.simmons/Desktop/NSS/data analytics bootcamp/capstone/Data/API_queries/ALDI_df.csv')
bi_rite = pd.read_csv('/Users/k.simmons/Desktop/NSS/data analytics bootcamp/capstone/Data/API_queries/bi_rite_df.csv')
food_lion = pd.read_csv('/Users/k.simmons/Desktop/NSS/data analytics bootcamp/capstone/Data/API_queries/food_lion_df.csv')
hg_hill = pd.read_csv('/Users/k.simmons/Desktop/NSS/data analytics bootcamp/capstone/Data/API_queries/HG_Hill_df.csv')
kroger = pd.read_csv('/Users/k.simmons/Desktop/NSS/data analytics bootcamp/capstone/Data/API_queries/kroger_df.csv')
piggly_wiggly = pd.read_csv('/Users/k.simmons/Desktop/NSS/data analytics bootcamp/capstone/Data/API_queries/piggly_wiggly_df.csv')
publix = pd.read_csv('/Users/k.simmons/Desktop/NSS/data analytics bootcamp/capstone/Data/API_queries/publix_df.csv')
save_a_lot = pd.read_csv('/Users/k.simmons/Desktop/NSS/data analytics bootcamp/capstone/Data/API_queries/save_a_lot_df.csv')
target = pd.read_csv('/Users/k.simmons/Desktop/NSS/data analytics bootcamp/capstone/Data/API_queries/target_df.csv')
trader_joes = pd.read_csv('/Users/k.simmons/Desktop/NSS/data analytics bootcamp/capstone/Data/API_queries/trader_joes_df.csv')
turnip_truck = pd.read_csv('/Users/k.simmons/Desktop/NSS/data analytics bootcamp/capstone/Data/API_queries/turnip_truck_df.csv')
walmart = pd.read_csv('/Users/k.simmons/Desktop/NSS/data analytics bootcamp/capstone/Data/API_queries/walmart_df.csv')
whole_foods = pd.read_csv('/Users/k.simmons/Desktop/NSS/data analytics bootcamp/capstone/Data/API_queries/whole_foods_df.csv')

# %%
merged_groceries = pd.concat([aldi, bi_rite, food_lion, hg_hill, kroger, piggly_wiggly, publix, save_a_lot, target, trader_joes, turnip_truck, walmart, whole_foods])

# %%
merged_groceries
# Out:
#     Unnamed: 0               shop_name  \
# 0          0.0                    ALDI
# 1          1.0                    ALDI
# 2          2.0                    ALDI
# 3          3.0                    ALDI
# 4          4.0                    ALDI
# ..         ...                     ...
# 84         NaN          Swett's Market
# 85         NaN        Aleksey's Market
# 86         NaN  Sprouts Farmers Market
# 87         NaN  Sprouts Farmers Market
# 88         NaN      Whole Foods Market
#
#                                   shop_address   shop_lat   shop_lng  \
# 0        615 Gallatin Ave, Nashville, TN 37206  36.183288 -86.747552
# 1      135 S. Gallatin Pike, Madison, TN 37115  36.261670 -86.711514
# 2         405 American Rd, Nashville, TN 37209  36.144960 -86.874036
# 3   3758 Nolensville Pike, Nashville, TN 37211  36.090287 -86.732314
# 4           7035 Hwy 70 S, Nashville, TN 37221  36.075043 -86.917644
# ..                                         ...        ...        ...
# ...

# %%
merged_groceries = merged_groceries.drop(columns= 'Unnamed: 0').reset_index(drop=True)
merged_groceries['zip_code'] = ''

# %%
merged_groceries
# Out:
#                    shop_name                                shop_address  \
# 0                       ALDI       615 Gallatin Ave, Nashville, TN 37206
# 1                       ALDI     135 S. Gallatin Pike, Madison, TN 37115
# 2                       ALDI        405 American Rd, Nashville, TN 37209
# 3                       ALDI  3758 Nolensville Pike, Nashville, TN 37211
# 4                       ALDI          7035 Hwy 70 S, Nashville, TN 37221
# ...                      ...                                         ...
# 2218          Swett's Market         702 28th Ave N, Nashville, TN 37208
# 2219        Aleksey's Market        718 Thompson Ln, Nashville, TN 37204
# 2220  Sprouts Farmers Market          7620 Hwy 70 S, Nashville, TN 37221
# 2221  Sprouts Farmers Market          7620 Hwy 70 S, Nashville, TN 37221
# 2222      Whole Foods Market            7825 US-72, Germantown, TN 38138
#
#        shop_lat   shop_lng                                              types  \
# ...

# %%
merged_groceries['shop_address'] = merged_groceries['shop_address'].astype(str)

n = 0
for i in merged_groceries['shop_address']:
    merged_groceries.at[n, 'zip_code'] = i[-5:]
    n += 1

merged_groceries
# Out:
#                    shop_name                                shop_address  \
# 0                       ALDI       615 Gallatin Ave, Nashville, TN 37206
# 1                       ALDI     135 S. Gallatin Pike, Madison, TN 37115
# 2                       ALDI        405 American Rd, Nashville, TN 37209
# 3                       ALDI  3758 Nolensville Pike, Nashville, TN 37211
# 4                       ALDI          7035 Hwy 70 S, Nashville, TN 37221
# ...                      ...                                         ...
# 2218          Swett's Market         702 28th Ave N, Nashville, TN 37208
# 2219        Aleksey's Market        718 Thompson Ln, Nashville, TN 37204
# 2220  Sprouts Farmers Market          7620 Hwy 70 S, Nashville, TN 37221
# 2221  Sprouts Farmers Market          7620 Hwy 70 S, Nashville, TN 37221
# 2222      Whole Foods Market            7825 US-72, Germantown, TN 38138
#
#        shop_lat   shop_lng                                              types  \
# ...

# %%
merged_groceries.to_csv('Data/merged_groceries.csv')
